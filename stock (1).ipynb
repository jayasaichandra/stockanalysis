# %%
###stocks analysis####

# %%
##Yahoo Finance	To download stock data
#Pandas	To handle data frames in python
#Numpy	Numerical Python
#Matplotlib	Plotting graphs
### upgrade python pip after importing yfinanace ###

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# !pip install yfinance
import yfinance as yf
# %matplotlib inline
import datetime
from datetime import timedelta
# Out:
# Requirement already satisfied: yfinance in c:\users\jay\anaconda3\lib\site-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\jay\anaconda3\lib\site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\jay\anaconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\jay\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: requests>=2.26 in c:\users\jay\anaconda3\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\jay\anaconda3\lib\site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jay\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jay\anaconda3\lib\site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\jay\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jay\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jay\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jay\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jay\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.2)

# %%
### date formats in yyyy-mm-dd with end date less than current day ######

# %%
### num = input("Enter the number of stocks to be analyzed: ") current condition not updated

date_entry = input('Enter the recent stock date in YYYY-MM-DD format')
year, month, day = map(int, date_entry.split('-'))
date1 = datetime.date(year, month, day)
start_date = str(date1)
default_month = date1 + timedelta(days=-30)
default_year = date1 + timedelta( days=-365)
default_five_year = date1 + timedelta( days=-365 *5)
# Out:
# Enter the recent stock date in YYYY-MM-DD format2022-05-19

# %%
start_date
# Out:
# '2022-05-19'

# %%
date_2 = datetime.date(year, month, day)
date_2 = str(default_month)
date_2
# Out:
# '2022-04-19'

# %%
date_3 = datetime.date(year, month, day)
date_3 = str(default_year)
date_3
# Out:
# '2021-05-19'

# %%
date_3 = datetime.date(year, month, day)
date_3 = str(default_five_year)
date_3
# Out:
# '2017-05-20'

# %%
### enter start and end date custom feature ###
##start = "2021-05-17"
##end = '2022-05-16'

# %%
### choose month, date and year functionality #### add month, year and 5 year functionality in if-else code

# %%
t1 = input("Enter the stock 1: ")
t2 = input("Enter the stock 2: ")
t3 = input("Enter the stock 3: ")

end = 'default_month'
fruit =input('enter "month" for recent month analysis \n enter "year" for recent year analysis \n enter "5 year" for 5 year analysis')
if fruit == 'month': 
    end = default_month;

elif fruit == "year": 
    end = default_year;

elif fruit == "5 year": 
    end = default_five_year

else: 
    print("")
# Out:
# Enter the stock 1: TSLA
# Enter the stock 2: GOOG
# Enter the stock 3: MSFT
# enter "month" for recent month analysis
#  enter "year" for recent year analysis
#  enter "5 year" for 5 year analysis5 year

# %%
stock_entry1 = yf.download(t1,end,start_date)
stock_entry2 = yf.download(t2,end,start_date)
stock_entry3 = yf.download(t3,end,start_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stock_entry1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-05-22   62.560001   62.874001   61.360001   62.070000   62.070000
# 2017-05-23   62.091999   62.146000   60.695999   60.771999   60.771999
# 2017-05-24   61.301998   62.200001   61.080002   62.043999   62.043999
# 2017-05-25   62.203999   63.394001   61.562000   63.366001   63.366001
# 2017-05-26   63.456001   65.098000   63.262001   65.028000   65.028000
# ...                ...         ...         ...         ...         ...
# 2022-05-12  701.000000  759.659973  680.000000  728.000000  728.000000
# 2022-05-13  773.479980  787.349976  751.570007  769.590027  769.590027
# 2022-05-16  767.159973  769.760010  719.090027  724.369995  724.369995
# 2022-05-17  747.359985  764.479980  728.849976  761.609985  761.609985
# 2022-05-18  744.520020  760.500000  700.809998  709.809998  709.809998
#
#               Volume
# Date
# 2017-05-22  21646000
# 2017-05-23  21592000
# 2017-05-24  25166500
# 2017-05-25  25070000
# 2017-05-26  39011000
# ...              ...
# 2022-05-12  46771000
# 2022-05-13  30651800
# 2022-05-16  28699500
# 2022-05-17  26745400
# 2022-05-18  29270600
#
# [1258 rows x 6 columns]

# %%
stock_entry2
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-05-22   935.000000   941.882996   935.000000   941.859985   941.859985
# 2017-05-23   947.919983   951.466980   942.575012   948.820007   948.820007
# 2017-05-24   952.979980   955.090027   949.500000   954.960022   954.960022
# 2017-05-25   957.330017   972.629028   955.469971   969.539978   969.539978
# 2017-05-26   969.700012   974.979980   965.030029   971.469971   971.469971
# ...                 ...          ...          ...          ...          ...
# 2022-05-12  2238.760010  2297.129883  2202.270020  2263.219971  2263.219971
# 2022-05-13  2296.909912  2361.699951  2280.000000  2330.310059  2330.310059
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
#
#              Volume
# Date
# 2017-05-22  1120400
# 2017-05-23  1270800
# 2017-05-24  1024800
# 2017-05-25  1660500
# 2017-05-26  1252000
# ...             ...
# 2022-05-12  2073200
# 2022-05-13  1486000
# 2022-05-16  1164100
# 2022-05-17  1078800
# 2022-05-18  1399100
#
# [1258 rows x 6 columns]

# %%
stock_entry3
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-05-22   67.889999   68.500000   67.500000   68.449997   64.113953
# 2017-05-23   68.720001   68.750000   68.379997   68.680000   64.329391
# 2017-05-24   68.870003   68.879997   68.449997   68.769997   64.413704
# 2017-05-25   68.970001   69.879997   68.910004   69.620003   65.209846
# 2017-05-26   69.800003   70.220001   69.519997   69.959999   65.528290
# ...                ...         ...         ...         ...         ...
# 2022-05-12  257.690002  259.880005  250.020004  255.350006  254.756653
# 2022-05-13  257.350006  263.040009  255.350006  261.119995  260.513245
# 2022-05-16  259.959991  265.820007  255.779999  261.500000  260.892365
# 2022-05-17  266.109985  268.329987  262.459991  266.820007  266.200012
# 2022-05-18  263.000000  263.600006  252.770004  254.080002  254.080002
#
#               Volume
# Date
# 2017-05-22  16237600
# 2017-05-23  15425800
# 2017-05-24  14593900
# 2017-05-25  21854100
# 2017-05-26  19827900
# ...              ...
# 2022-05-12  51033800
# 2022-05-13  34893400
# 2022-05-16  32550900
# 2022-05-17  28828800
# 2022-05-18  31356000
#
# [1258 rows x 6 columns]

# %%
stock_entry1['Open'].plot(label = t1, figsize = (15,7))
stock_entry2['Open'].plot(label = t2)
stock_entry3['Open'].plot(label = t3)
plt.title('Enter stocks are = '+str(t1)+" "+str(t2)+" "+str(t3))
plt.legend()

# %%
stock_entry1['High'].plot(label = t1, figsize = (15,7))
stock_entry2['High'].plot(label = t2)
stock_entry3['High'].plot(label = t3)
plt.title('Enter stocks are = '+str(t1)+" "+str(t2)+" "+str(t3))
plt.legend()

# %%
# volume of stock traded ###

# %%
stock_entry1['Volume'].plot(label = t1, figsize = (15,7))
stock_entry2['Volume'].plot(label = t2)
stock_entry3['Volume'].plot(label = t3)
plt.title('Volume of Stock traded')
plt.legend()

# %%
#Market Capitalisation
stock_entry1['MarktCap'] = stock_entry1['Open'] * stock_entry1['Volume']
stock_entry2['MarktCap'] = stock_entry2['Open'] * stock_entry2['Volume']
stock_entry3['MarktCap'] = stock_entry3['Open'] * stock_entry3['Volume']
stock_entry1['MarktCap'].plot(label = t1, figsize = (20,5))
stock_entry2['MarktCap'].plot(label = t2)
stock_entry3['MarktCap'].plot(label = t3)
plt.title('Market Cap')
plt.legend()

# %%
## Rolling the tcs stock with max limit 200 moving avaerage ##

# %%
###Individual weighted average

# %%
tc_code = input("Enter the stock code: ")
if t1 == tc_code: 
    stock_entry1['MA50'] = stock_entry1['Open'].rolling(50).mean()
    stock_entry1['MA200'] = stock_entry1['Open'].rolling(200).mean()
    stock_entry1['Open'].plot(figsize = (15,7))
    stock_entry1['MA50'].plot()
    stock_entry1['MA200'].plot()

elif t2 == tc_code: 
    stock_entry2['MA50'] = stock_entry2['Open'].rolling(50).mean()
    stock_entry2['MA200'] = stock_entry2['Open'].rolling(200).mean()
    stock_entry2['Open'].plot(figsize = (15,7))
    stock_entry2['MA50'].plot()
    stock_entry2['MA200'].plot()

elif t3 == tc_code: 
    stock_entry3['MA50'] = stock_entry3['Open'].rolling(50).mean()
    stock_entry3['MA200'] = stock_entry3['Open'].rolling(200).mean()
    stock_entry3['Open'].plot(figsize = (15,7))
    stock_entry3['MA50'].plot()
    stock_entry3['MA200'].plot()

else: 
    print("")
# Out:
# Enter the stock code: TSLA

# %%
data = pd.concat([stock_entry1['Open'],stock_entry2['Open'], stock_entry3['Open']],axis = 1)
data.columns = [t1, t2, t3]
scatter_matrix(data, figsize = (8,8), hist_kwds= {'bins':250})
# Out:
# array([[<AxesSubplot:xlabel='TSLA', ylabel='TSLA'>,
#         <AxesSubplot:xlabel='GOOG', ylabel='TSLA'>,
#         <AxesSubplot:xlabel='MSFT', ylabel='TSLA'>],
#        [<AxesSubplot:xlabel='TSLA', ylabel='GOOG'>,
#         <AxesSubplot:xlabel='GOOG', ylabel='GOOG'>,
#         <AxesSubplot:xlabel='MSFT', ylabel='GOOG'>],
#        [<AxesSubplot:xlabel='TSLA', ylabel='MSFT'>,
#         <AxesSubplot:xlabel='GOOG', ylabel='MSFT'>,
#         <AxesSubplot:xlabel='MSFT', ylabel='MSFT'>]], dtype=object)

# %%
#Volatility
stock_entry1['returns'] = (stock_entry1['Close']/stock_entry1['Close'].shift(1)) -1
stock_entry2['returns'] = (stock_entry2['Close']/stock_entry2['Close'].shift(1)) -1
stock_entry3['returns'] = (stock_entry3['Close']/stock_entry3['Close'].shift(1)) -1
stock_entry1['returns'].hist(bins = 100, label = t1, alpha = 0.5, figsize = (15,7))
stock_entry2['returns'].hist(bins = 100, label = t2, alpha = 0.5)
stock_entry3['returns'].hist(bins = 100, label = t3, alpha = 0.5)
plt.legend()

# %%
stock_entry1['Volume'].plot(label = t1, figsize = (15,7))
stock_entry2['Volume'].plot(label = t2)
stock_entry3['Volume'].plot(label = t3)
plt.title('Enter stocks are = '+str(t1)+" "+str(t2)+" "+str(t3))
plt.legend()
