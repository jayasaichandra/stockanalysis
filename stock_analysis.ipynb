# %%
###stocks analysis####

# %%
##Yahoo Finance	To download stock data
#Pandas	To handle data frames in python
#Numpy	Numerical Python
#Matplotlib	Plotting graphs
### upgrade python pip after importing yfinanace ###

# %%
import pandas as pd

import datetime

import numpy as np

import matplotlib.pyplot as plt

from pandas.plotting import scatter_matrix

# !pip install yfinance

import yfinance as yf

# %matplotlib inline

import datetime
from datetime import timedelta
# Out:
# Requirement already satisfied: yfinance in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.1.70)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (1.2.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: numpy>=1.15 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: requests>=2.26 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=0.24.0->yfinance) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=0.24.0->yfinance) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.26->yfinance) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.26->yfinance) (1.26.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: six>=1.5 in c:\users\jay\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)

# %%
### date formats in yyyy-mm-dd with end date less than current day ######

# %%
### num = input("Enter the number of stocks to be analyzed: ")

date_entry = input('Enter the recent stock date in YYYY-MM-DD format')
year, month, day = map(int, date_entry.split('-'))
date1 = datetime.date(year, month, day)
start_date = str(date1)
default_month = date1 + timedelta(days=-30)
default_year = date1 + timedelta( days=-365)
default_five_year = date1 + timedelta( days=-365 *5)
# Out:
# Enter the recent stock date in YYYY-MM-DD format2022-05-15

# %%
start_date
# Out:
# '2022-05-15'

# %%
date_2 = datetime.date(year, month, day)
date_2 = str(default_month)
date_2
# Out:
# '2022-04-15'

# %%
date_3 = datetime.date(year, month, day)
date_3 = str(default_year)
date_3
# Out:
# '2021-05-15'

# %%
date_3 = datetime.date(year, month, day)
date_3 = str(default_five_year)
date_3
# Out:
# '2017-05-16'

# %%
### enter start and end date custom feature ###
##start = "2021-05-17"
##end = '2022-05-16'

# %%
### choose month, date and year functionality ####

# %%
t1 = input("Enter the stock 1: ")
t2 = input("Enter the stock 2: ")
t3 = input("Enter the stock 3: ")

end = 'default_month'
fruit =input('enter "month" for recent month analysis \n enter "year" for recent year analysis \n enter "5 year" for 5 year analysis')
if fruit == 'month': 
    end = default_month;

elif fruit == "year": 
    end = default_year;

elif fruit == "5 year": 
    end = default_five_year

else: 
    print("")
# Out:
# Enter the stock 1: GOOG
# Enter the stock 2: AMZN
# Enter the stock 3: MSFT
# enter "month" for recent month analysis
#  enter "year" for recent year analysis
#  enter "5 year" for 5 year analysisyear

# %%
stock_entry1 = yf.download(t1,end,start_date)
stock_entry2 = yf.download(t2,end,start_date)
stock_entry3 = yf.download(t3,end,start_date)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
stock_entry1
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-05-17  2309.320068  2323.340088  2295.000000  2321.409912  2321.409912
# 2021-05-18  2336.906006  2343.149902  2303.159912  2303.429932  2303.429932
# 2021-05-19  2264.399902  2316.760010  2263.520020  2308.709961  2308.709961
# 2021-05-20  2328.040039  2360.340088  2321.090088  2356.090088  2356.090088
# 2021-05-21  2365.989990  2369.000000  2342.370117  2345.100098  2345.100098
# ...                 ...          ...          ...          ...          ...
# 2022-05-09  2266.070068  2311.258057  2251.030029  2261.679932  2261.679932
# 2022-05-10  2320.810059  2333.820068  2267.666016  2291.689941  2291.689941
# 2022-05-11  2274.209961  2333.419922  2273.000000  2279.219971  2279.219971
# 2022-05-12  2238.760010  2297.129883  2202.270020  2263.219971  2263.219971
# 2022-05-13  2296.909912  2361.699951  2280.000000  2330.310059  2330.310059
#
#              Volume
# Date
# 2021-05-17   992100
# 2021-05-18   865100
# 2021-05-19   967500
# 2021-05-20  1191600
# 2021-05-21  1141600
# ...             ...
# 2022-05-09  1726000
# 2022-05-10  1557900
# 2022-05-11  1825100
# 2022-05-12  2073200
# 2022-05-13  1486000
#
# [252 rows x 6 columns]

# %%
stock_entry2
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-05-17  3245.929932  3292.750000  3234.590088  3270.389893  3270.389893
# 2021-05-18  3292.580078  3312.000000  3230.370117  3232.280029  3232.280029
# 2021-05-19  3195.000000  3234.750000  3184.000000  3231.800049  3231.800049
# 2021-05-20  3244.399902  3259.679932  3236.179932  3247.679932  3247.679932
# 2021-05-21  3250.000000  3256.689941  3197.010010  3203.080078  3203.080078
# ...                 ...          ...          ...          ...          ...
# 2022-05-09  2226.250000  2280.000000  2159.139893  2175.780029  2175.780029
# 2022-05-10  2225.000000  2252.850098  2143.419922  2177.179932  2177.179932
# 2022-05-11  2162.070068  2203.120117  2088.570068  2107.439941  2107.439941
# 2022-05-12  2055.000000  2215.610107  2048.110107  2138.610107  2138.610107
# 2022-05-13  2181.379883  2263.679932  2156.000000  2261.100098  2261.100098
#
#              Volume
# Date
# 2021-05-17  3723900
# 2021-05-18  2828400
# 2021-05-19  2679700
# 2021-05-20  2633200
# 2021-05-21  4104900
# ...             ...
# 2022-05-09  6406200
# 2022-05-10  5271700
# 2022-05-11  5485200
# 2022-05-12  6601300
# 2022-05-13  4676700
#
# [252 rows x 6 columns]

# %%
stock_entry3
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-05-17  246.550003  246.589996  243.520004  245.179993  243.199036
# 2021-05-18  246.270004  246.410004  242.899994  243.080002  241.115997
# 2021-05-19  239.309998  243.229996  238.600006  243.119995  241.712524
# 2021-05-20  243.960007  247.949997  243.860001  246.479996  245.053070
# 2021-05-21  247.570007  248.330002  244.740005  245.169998  243.750656
# ...                ...         ...         ...         ...         ...
# 2022-05-09  270.059998  272.359985  263.320007  264.579987  264.579987
# 2022-05-10  271.690002  273.750000  265.070007  269.500000  269.500000
# 2022-05-11  265.679993  271.359985  259.299988  260.549988  260.549988
# 2022-05-12  257.690002  259.880005  250.020004  255.350006  255.350006
# 2022-05-13  257.350006  263.040009  255.350006  261.119995  261.119995
#
#               Volume
# Date
# 2021-05-17  24970200
# 2021-05-18  20168000
# 2021-05-19  25739800
# 2021-05-20  21800700
# 2021-05-21  21863100
# ...              ...
# 2022-05-09  47726000
# 2022-05-10  39336400
# 2022-05-11  48975900
# 2022-05-12  51033800
# 2022-05-13  34893400
#
# [252 rows x 6 columns]

# %%
stock_entry1['Open'].plot(label = t1, figsize = (15,7))
stock_entry2['Open'].plot(label = t2)
stock_entry3['Open'].plot(label = t3)
plt.title('Enter stocks are = '+str(t1)+" "+str(t2)+" "+str(t3))
plt.legend()

# %%
stock_entry1['High'].plot(label = t1, figsize = (15,7))
stock_entry2['High'].plot(label = t2)
stock_entry3['High'].plot(label = t3)
plt.title('Enter stocks are = '+str(t1)+" "+str(t2)+" "+str(t3))
plt.legend()

# %%
# volume of stock traded ###

# %%
stock_entry1['Volume'].plot(label = t1, figsize = (15,7))
stock_entry2['Volume'].plot(label = t2)
stock_entry3['Volume'].plot(label = t3)
plt.title('Volume of Stock traded')
plt.legend()

# %%
#Market Capitalisation
stock_entry1['MarktCap'] = stock_entry1['Open'] * stock_entry1['Volume']
stock_entry2['MarktCap'] = stock_entry2['Open'] * stock_entry2['Volume']
stock_entry3['MarktCap'] = stock_entry3['Open'] * stock_entry3['Volume']
stock_entry1['MarktCap'].plot(label = 'TCS', figsize = (20,5))
stock_entry2['MarktCap'].plot(label = 'Infosys')
stock_entry3['MarktCap'].plot(label = 'Wipro')
plt.title('Market Cap')
plt.legend()

# %%
## Rolling the tcs stock with max limit 200 moving avaerage ##

# %%
###Individual weighted average

# %%
tc_code = input("Enter the stock code: ")
if t1 == tc_code: 
    stock_entry1['MA50'] = stock_entry1['Open'].rolling(50).mean()
    stock_entry1['MA200'] = stock_entry1['Open'].rolling(200).mean()
    stock_entry1['Open'].plot(figsize = (15,7))
    stock_entry1['MA50'].plot()
    stock_entry1['MA200'].plot()

elif t2 == tc_code: 
    stock_entry2['MA50'] = stock_entry2['Open'].rolling(50).mean()
    stock_entry2['MA200'] = stock_entry2['Open'].rolling(200).mean()
    stock_entry2['Open'].plot(figsize = (15,7))
    stock_entry2['MA50'].plot()
    stock_entry2['MA200'].plot()

elif t3 == tc_code: 
    stock_entry3['MA50'] = stock_entry3['Open'].rolling(50).mean()
    stock_entry3['MA200'] = stock_entry3['Open'].rolling(200).mean()
    stock_entry3['Open'].plot(figsize = (15,7))
    stock_entry3['MA50'].plot()
    stock_entry3['MA200'].plot()

else: 
    print("")
# Out:
# Enter the stock code: AMZN

# %%
data = pd.concat([stock_entry1['Open'],stock_entry2['Open'], stock_entry3['Open']],axis = 1)
data.columns = [t1, t2, t3]
scatter_matrix(data, figsize = (8,8), hist_kwds= {'bins':250})
# Out:
# array([[<AxesSubplot:xlabel='GOOG', ylabel='GOOG'>,
#         <AxesSubplot:xlabel='AMZN', ylabel='GOOG'>,
#         <AxesSubplot:xlabel='MSFT', ylabel='GOOG'>],
#        [<AxesSubplot:xlabel='GOOG', ylabel='AMZN'>,
#         <AxesSubplot:xlabel='AMZN', ylabel='AMZN'>,
#         <AxesSubplot:xlabel='MSFT', ylabel='AMZN'>],
#        [<AxesSubplot:xlabel='GOOG', ylabel='MSFT'>,
#         <AxesSubplot:xlabel='AMZN', ylabel='MSFT'>,
#         <AxesSubplot:xlabel='MSFT', ylabel='MSFT'>]], dtype=object)

# %%
#Volatility
stock_entry1['returns'] = (stock_entry1['Close']/stock_entry1['Close'].shift(1)) -1
stock_entry2['returns'] = (stock_entry2['Close']/stock_entry2['Close'].shift(1)) -1
stock_entry3['returns'] = (stock_entry3['Close']/stock_entry3['Close'].shift(1)) -1
stock_entry1['returns'].hist(bins = 100, label = 'TCS', alpha = 0.5, figsize = (15,7))
stock_entry2['returns'].hist(bins = 100, label = 'Infosysy', alpha = 0.5)
stock_entry3['returns'].hist(bins = 100, label = 'Wipro', alpha = 0.5)
plt.legend()
